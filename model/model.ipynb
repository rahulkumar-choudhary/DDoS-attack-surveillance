# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

# %%
dtypes = {
    'ip.src': 'object',
    'ip.dst': 'object',
    'ip.proto': 'int64',
    'frame.len': 'int64',
    'tcp.srcport': 'int64',
    'tcp.dstport': 'int64', 
    'tcp.seq': 'int64',
    'tcp.ack': 'int64', 
    'Bytes': 'int64',  
    'Label': 'object'
}

# %%
nRowsRead = None # specify 'None' if want to read whole file

dataset = pd.read_csv(
    '../data/DDoS-Dataset.csv',
    dtype=dtypes,
    engine='c',
    low_memory=True,
    delimiter=',', 
    nrows = nRowsRead
)

dataset.dataframeName = 'DDoS-Dataset.csv'

nRow, nCol = dataset.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 151200 rows and 23 columns

# %%
ddrop = ['tcp.flags.syn', 'tcp.flags.reset', 'tcp.flags.push', 'tcp.flags.ack', 'ip.flags.mf', 'ip.flags.df', 'ip.flags.rb', 'frame.time', 'Packets', 'Tx Packets', 'Tx Bytes', 'Rx Packets', 'Rx Bytes' ]
dataset.drop(ddrop, inplace=True, axis=1)

# rename Bytes with tcp.len
dataset.rename(columns={'Bytes': 'tcp.len'}, inplace=True)

dataset.head(5)
# Out:
#         ip.src        ip.dst  tcp.srcport  tcp.dstport  ip.proto  frame.len  \
# 0  192.168.1.1  192.168.23.2         2412         8000         6         54
# 1  192.168.1.1  192.168.23.2         2413         8000         6         54
# 2  192.168.1.1  192.168.23.2         2414         8000         6         54
# 3  192.168.1.1  192.168.23.2         2415         8000         6         54
# 4  192.168.1.1  192.168.23.2         2416         8000         6         54
#
#    tcp.seq  tcp.ack  tcp.len         Label
# 0        1        1      432  DDoS-PSH-ACK
# 1        1        1      540  DDoS-PSH-ACK
# 2        1        1      648  DDoS-PSH-ACK
# 3        1        1      540  DDoS-PSH-ACK
# 4        1        1      324  DDoS-PSH-ACK

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151200 entries, 0 to 151199
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ip.src       151200 non-null  object
#  1   ip.dst       151200 non-null  object
#  2   tcp.srcport  151200 non-null  int64
#  3   tcp.dstport  151200 non-null  int64
#  4   ip.proto     151200 non-null  int64
#  5   frame.len    151200 non-null  int64
#  6   tcp.seq      151200 non-null  int64
#  7   tcp.ack      151200 non-null  int64
#  8   tcp.len      151200 non-null  int64
#  9   Label        151200 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 11.5+ MB

# %%
def ip_to_int(ip):
    parts = ip.split('.')
    return int(''.join([part.zfill(3) for part in parts]))

# # Apply the custom function to the "ip_address" column
dataset['ip.src'] = dataset['ip.src'].apply(ip_to_int)
dataset['ip.dst'] = dataset['ip.dst'].apply(ip_to_int)

# %%
# replace 1 and 0 for ddos or not
def label_update(label):
    if label == 'DDoS-PSH-ACK' or label == 'DDoS-ACK':
        return 1
    elif label == 'Benign':
        return 0

dataset['Label'] = dataset['Label'].apply(label_update)

# %%
dataset.describe(include='all')
# Out:
#              ip.src        ip.dst    tcp.srcport  tcp.dstport  ip.proto  \
# count  1.512000e+05  1.512000e+05  151200.000000     151200.0  151200.0
# mean   1.921680e+11  1.921680e+11   27376.943247       8000.0       6.0
# std    6.020817e+03  0.000000e+00   19634.879546          0.0       0.0
# min    1.921680e+11  1.921680e+11    1302.000000       8000.0       6.0
# 25%    1.921680e+11  1.921680e+11    8621.000000       8000.0       6.0
# 50%    1.921680e+11  1.921680e+11   26263.000000       8000.0       6.0
# 75%    1.921680e+11  1.921680e+11   45566.000000       8000.0       6.0
# max    1.921680e+11  1.921680e+11   60998.000000       8000.0       6.0
#
#            frame.len   tcp.seq   tcp.ack        tcp.len          Label
# count  151200.000000  151200.0  151200.0  151200.000000  151200.000000
# mean       99.025126       1.0       1.0     799.422937       0.500000
# std        71.226673       0.0       0.0     373.759057       0.500002
# min        54.000000       1.0       1.0      54.000000       0.000000
# 25%        54.000000       1.0       1.0     432.000000       0.000000
# 50%        60.000000       1.0       1.0    1101.500000       0.500000
# 75%       105.000000       1.0       1.0    1146.000000       1.000000
# max       223.000000       1.0       1.0    1229.000000       1.000000

# %%
# search for missing value
#dataset.isna().sum()

X = dataset.drop('Label', axis=1).values
y = dataset['Label'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=32)

# %%
# readymade model
from sklearn.ensemble import GradientBoostingClassifier

# Create a Gradient Boosting classifier object
gb_classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=0.2, max_depth=4)

# %%
# Train the classifier on the training data
gb_classifier.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.2, max_depth=4)

# %%
from sklearn.metrics import accuracy_score

# Predict the labels of the test data
y_pred = gb_classifier.predict(X_test)

# Evaluate the accuracy of the classifier
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0

# %%
# save the model
import pickle

filename = './done/ddos_model.pkl'
pickle.dump(gb_classifier, open(filename, 'wb'))

# %%
import pandas as pd
import numpy as np
import pickle

loaded_model = pickle.load(open('./done/ddos_model.pkl', 'rb'))
# result = loaded_model.score(X_test, y_test)
# print(result)

# %%
# realtime attack prediction
saved_data = pd.read_csv('../data/prddata.csv')

saved_data.head(5)
# Out:
#            ip.src          ip.dst  ip.proto  frame.len  tcp.srcport  \
# 0   140.82.112.26     192.168.1.5         6         92          443
# 1     192.168.1.5   140.82.112.26         6         96        35398
# 2   140.82.112.26     192.168.1.5         6         66          443
# 3  192.168.59.110    23.57.12.251         6         66        40184
# 4    23.57.12.251  192.168.59.110         6         97          443
#
#    tcp.dstport  tcp.seq  tcp.ack  tcp.len
# 0        35398        1        1       26
# 1          443        1       27       30
# 2        35398       27       31        0
# 3          443        1        1        0
# 4        40184        1        2       31

# %%
def ip_to_int(ip):
    parts = ip.split('.')
    return int(''.join([part.zfill(3) for part in parts]))

# # Apply the custom function to the "ip_address" column
saved_data['ip.src'] = saved_data['ip.src'].apply(ip_to_int)
saved_data['ip.dst'] = saved_data['ip.dst'].apply(ip_to_int)

saved_data.head(5)
# Out:
#          ip.src        ip.dst  ip.proto  frame.len  tcp.srcport  tcp.dstport  \
# 0  140082112026  192168001005         6         92          443        35398
# 1  192168001005  140082112026         6         96        35398          443
# 2  140082112026  192168001005         6         66          443        35398
# 3  192168059110   23057012251         6         66        40184          443
# 4   23057012251  192168059110         6         97          443        40184
#
#    tcp.seq  tcp.ack  tcp.len
# 0        1        1       26
# 1        1       27       30
# 2       27       31        0
# 3        1        1        0
# 4        1        2       31

# %%
# pred = loaded_model.predict(saved_data)

#X = np.delete(X, (0), axis=0)

pred = loaded_model.predict(X)

print("\n\nPredicted values:\n")
d=0
n=0
for i in pred:
    if i==1:
        d+=1
    elif i==0:
        n+=1
        
print(f"Predicted DDoS attack: {d}")
print(f"Predicted noraml call: {n}")
# Out:
# Predicted values:
#
# Predicted DDoS attack: 75600
# Predicted noraml call: 75600
